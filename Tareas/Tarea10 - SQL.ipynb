# %%
import mysql.connector
import pandas as pd
import os
import os
import getpass
# Poner sus variables de ambiente
os.environ["MYSQL_HOST"] = "localhost"
os.environ["MYSQL_PORT"] = "3306"
os.environ["MYSQL_USER"] = "root"
os.environ["MYSQL_DATABASE"] = "biblioteca"

os.environ["MYSQL_PASSWORD"] = getpass.getpass(
    "Contraseña de MySQL: "
)

# %%
host=os.environ["MYSQL_HOST"]
port=os.environ["MYSQL_PORT"]
user=os.environ["MYSQL_USER"] 
password=os.environ["MYSQL_PASSWORD"]
database=os.environ["MYSQL_DATABASE"]

# %%
connection = mysql.connector.connect(
    host=host,
    port=port,
    user=user, 
    password=password,
    database=database
)

# %%
cursor = connection.cursor()

# %%
def consulta(sql):
    cursor = connection.cursor()
    cursor.execute(sql)
    filas= cursor.fetchall()
    #print(filas)
    columnas = [
        columna[0]
        for columna in cursor.description
    ]
    #print(columnas)
    cursor.close()
    return pd.DataFrame(
        filas,
        columns=columnas
    )

# %%
df_productos = consulta("""
    SELECT * 
    FROM productos
""")

# %%
df_productos.head()
# Out:
#    producto_id     nombre   precio  stock  categoria_id
# 0            1  Audífonos  1200.00     10             1
# 1            2      Mouse   450.00     20             1
# 2            3    Lámpara   800.00      8             2
# 3            4      Silla  1800.00      5             2
# 4            5   Pantalón   900.00     12             3

# %%
df_productos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   producto_id   12 non-null     int64
#  1   nombre        12 non-null     str
#  2   precio        12 non-null     object
#  3   stock         12 non-null     int64
#  4   categoria_id  12 non-null     int64
# dtypes: int64(3), object(1), str(1)
# memory usage: 702.0+ bytes
